# %% [markdown]
# <a href="https://colab.research.google.com/github/janhvivatsa/numpyyyy/blob/main/untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],

    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],

    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
b=np.sum(s,axis=1)
print(b)
# Out:
# [45 45 45 45 45 45 45 45 45]

# %%
import numpy as np

c = np.sum(s, axis=0)

if (c == 45).all():
    print("valid")
else:
    print("not valid")
# Out:
# valid

# %%
c=np.sum([0,:2b])

# %%
for i in range(0,9,3):
  for j in range (0,9,3):
    n=s[i:i+3,j:j+3]
    print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %%
print(n)
# Out:
# [[2 8 4]
#  [6 3 5]
#  [1 7 9]]

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
data.shape
# Out:
# (5, 3)

# %%
np.mean(data[:,0])
# Out:
# np.float64(18.4)

# %%
print(data[:,1])
# Out:
# [85 92 76 65 90]

# %%
np.max(data[:,2])
# Out:
# np.int64(95)

# %%
data[:,1]+5
# Out:
# array([90, 97, 81, 70, 95])

# %%
count=0
for i in data[:,0]:
  if i>19:
    count+=1
print(count)
# Out:
# 1

# %%
np.mean(data[:,1],axis=0)
# Out:
# np.float64(81.6)
